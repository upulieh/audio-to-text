# %%
# !pip install git+https://github.com/openai/whisper.git
# !sudo apt update && sudo apt install ffmpeg
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-t1dxlq6p
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-t1dxlq6p
#   Resolved https://github.com/openai/whisper.git to commit 0a60fcaa9b86748389a656aa013c416030287d47
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 24.2 MB/s eta 0:00:00
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20230918-py3-none-any.whl size=798399 sha256=8f638b84cd2d61d807ea89c4784c793579ffbfc8681fabf356d7afa378495683
#   Stored in directory: /tmp/pip-ephem-wheel-cache-vl88v6x2/wheels/8b/6c/d0/622666868c179f156cf595c8b6f06f88bc5d80c4b31dccaa03
# Successfully built openai-whisper
# ...
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# ...

# %%
# models available are - tiny, base, small, medium, large
# !whisper "sample.mp3" --model medium --language de
# Out:
# 100%|██████████████████████████████████████| 1.42G/1.42G [00:15<00:00, 102MiB/s]
# [00:00.000 --> 00:08.000]  Herzlich willkommen zu diesem Video für Erstsemester. Ich freue mich, dass Sie sich dazu entschlossen haben, ein Studium an der Universität des Saarlandes aufzunehmen.
# [00:08.000 --> 00:12.000]  Mein Name ist Peter Hell, ich arbeite in der Zentralen Studienberatung.
# [00:12.000 --> 00:17.000]  Wir unterstützen Sie gerne beim Übergang von der Schule zur Universität und auch darüber hinaus.
# [00:17.000 --> 00:27.000]  In diesem Video möchte ich Ihnen einen Überblick darüber geben, was die wichtigsten ersten Schritte sind, um die Zeit bis zum Veranstaltungsbeginn möglichst gut zu nutzen.
# [00:27.000 --> 00:31.000]  Beginnen wir mit der UDS-Kennung und der UDS-Card.
# ...

# %% [markdown]
# # srt, txt, vtt files would be available after running the above

# %%
# !whisper -h
# Out:
# usage: whisper
#        [-h]
#        [--model {tiny.en,tiny,base.en,base,small.en,small,medium.en,medium,large-v1,large-v2,large}]
#        [--model_dir MODEL_DIR]
#        [--device DEVICE]
#        [--output_dir OUTPUT_DIR]
#        [--output_format {txt,vtt,srt,tsv,json,all}]
#        [--verbose VERBOSE]
#        [--task {transcribe,translate}]
# ...
